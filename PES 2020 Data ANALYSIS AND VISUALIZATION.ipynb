# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv(r"C:\Users\seyi\Downloads\efootball-pes-2020-all-players-csv\deets-updated.csv")

# %%
data.head()
# Out:
#              name shirt_number          team_name                  league  \
# 0          NEYMAR           10                PSG       Ligue 1 Conforama
# 1        M. NEUER            1  FC BAYERN MÜNCHEN  Other European Leagues
# 2  EDU CAMPABADAL           22            LUGO RB    Spanish 2nd Division
# 3       FRAN CRUZ            5     EXTREMADURA AR    Spanish 2nd Division
# 4   DANI PINILLOS           23         BARNSLEY R    English 2nd Division
#
#   nationality         region  height  weight  age        foot  ...  \
# 0      BRAZIL  South America     175      68   27  Right foot  ...
# 1     GERMANY         Europe     193      92   33  Right foot  ...
# 2       SPAIN         Europe     178      77   26  Right foot  ...
# 3       SPAIN         Europe     184      73   28  Right foot  ...
# 4       SPAIN         Europe     183      74   27   Left foot  ...
#
#   com_playing_style_incisive_run com_playing_style_early_cross  \
# ...

# %%
data.shape
# Out:
# (15035, 124)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                  name shirt_number          team_name  \
# 0              NEYMAR           10                PSG
# 1            M. NEUER            1  FC BAYERN MÜNCHEN
# 2      EDU CAMPABADAL           22            LUGO RB
# 3           FRAN CRUZ            5     EXTREMADURA AR
# 4       DANI PINILLOS           23         BARNSLEY R
# ...               ...          ...                ...
# 15030        A. BORUC            1     BOURNEMOUTH RB
# 15031       C. GORDON            1             CELTIC
# 15032        C. BRAVO            1       MANCHESTER B
# 15033    A. RODRÍGUEZ            5       ALIANZA LIMA
# 15034       G. BUFFON           77           JUVENTUS
#
#                            league nationality         region  height  weight  \
# 0               Ligue 1 Conforama      BRAZIL  South America     175      68
# 1          Other European Leagues     GERMANY         Europe     193      92
# ...

# %%
def country(x):
    return data[data['nationality'] == x][['name','shirt_number','age','registered_position','ball_color']]
country('SPAIN')
# Out:
#                  name shirt_number  age registered_position ball_color
# 2      EDU CAMPABADAL           22   26                  RB      white
# 3           FRAN CRUZ            5   28                  CB      white
# 4       DANI PINILLOS           23   27                  LB      white
# 6         JUAN CARLOS            1   31                  GK     bronze
# 7       BERNARDO CRUZ           16   26                  CB      white
# ...               ...          ...  ...                 ...        ...
# 15021     DIEGO LÓPEZ           13   38                  GK     silver
# 15022    ASIER RIESGO           13   36                  GK     silver
# 15024   SANTI CAZORLA            8   35                 CMF       gold
# 15025     JAVI GARCÍA            3   32                 DMF     silver
# 15026           RUBÉN           13   35                  GK     silver
#
# [971 rows x 5 columns]

# %%
def country(x):
    return data[data['nationality'] == x][['name','shirt_number','age','registered_position','ball_color']]
country('NIGERIA')
# Out:
#                   name shirt_number  age registered_position ball_color
# 5            N. OBIORA            4   28                 DMF      white
# 397         I. EZEKIEL           39   26                  CF     bronze
# 564          A. AJAGUN            8   26                 AMF      white
# 837           A. ESITI           24   25                 DMF     bronze
# 945         I. SUCCESS           22   23                  CF     bronze
# ...                ...          ...  ...                 ...        ...
# 13523         O. ONAZI           23   27                 DMF     silver
# 14291         R. AZEEZ           12   27                 CMF     bronze
# 14317  W. TROOST-EKONG            5   26                  CB     silver
# 14420             SIMY           25   27                  CF     silver
# 14456         C. AKPOM           47   24                  CF      white
#
# [78 rows x 5 columns]
